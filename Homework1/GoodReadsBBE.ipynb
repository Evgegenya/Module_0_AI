# %% [markdown]
# Создание EDA-отчёта по датасету Goodreads Best Books Ever dataset.
#
# Ссылка на Colab:
# https://colab.research.google.com/drive/1PL8sor8gPXGcG12jmDoV5gopu9YlrSVA#scrollTo=31fTCUtvmkvQ

# %% [markdown]
# Goodreads Best Books Ever dataset

# %%
pip install fg-data-profiling

# %%
import pandas as pd

df = pd.read_csv(r'https://github.com/Evgegenya/Module_0_AI/raw/refs/heads/main/Goodreads_BestBooksEver.csv')

# %% [markdown]
# Отчёт

# %%
import pandas as pd
from data_profiling import ProfileReport

profile = ProfileReport(
    df,
    title="GoodReadsBBE — EDA Отчет",
    explorative=True
)

# Отобразить в Colab
profile.to_notebook_iframe()

#profile.to_file("eda_report.html")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from google.colab import drive
drive.mount('/content/drive')
